# %%
import pandas as pd
crime = pd.read_csv("https://data.wprdc.org/datastore/dump/044f2016-1dfd-4ab0-bc1e-065da05fca2e")

# %%
crime.head()

# %% [markdown]
# Only want to extract the most recent 3 years' data

# %%
crime['INCIDENTTIME'] = pd.to_datetime(crime['INCIDENTTIME'])
crime = crime[crime['INCIDENTTIME'] >= '2022-01-01']
crime.head()
# Out:
#            _id       PK         CCR  HIERARCHY        INCIDENTTIME  \
# 266255  280537  3277328  22002393.0         29 2022-01-05 23:46:00
# 266336  280652  3277501  22000764.0         99 2022-01-02 14:47:00
# 266467  280783  3277798  22000195.0         10 2022-01-01 06:32:00
# 267618  281991  3279683  21224052.0         99 2022-01-06 11:00:00
# 268314  282724  3280962  22004012.0          1 2022-01-08 16:00:00
#
#                                      INCIDENTLOCATION CLEAREDFLAG  \
# 266255     1100 Block Liberty AV Pittsburgh, PA 15222           Y
# 266336  2600 Block Palisade LANE Pittsburgh, PA 15214           Y
# 266467      2500 Block Spring ST Pittsburgh, PA 15210           Y
# 267618                                         Zone 2           Y
# 268314      300 Block Reifert ST Pittsburgh, PA 15210           N
#
#              INCIDENTNEIGHBORHOOD INCIDENTZONE         INCIDENTHIERARCHYDESC  \
# 266255  Central Business District            2           RUNAWAYS - JUVENILE
# 266336                Perry South            1                           NaN
# 266467                  Arlington            3         SIMPLE ASSAULT/INJURY
# 267618                        NaN            2                           NaN
# 268314                  Knoxville            3  MURDER/NON-NEG/MANSLTR-KNIFE
#
#                                     OFFENSES  INCIDENTTRACT  COUNCIL_DISTRICT  \
# 266255                  029 Missing Juvenile          201.0               7.0
# 266336                       9497 Aided Case         2615.0               NaN
# 266467                  2701 Simple Assault.         1603.0               7.0
# 267618  9999 Miscellaneous Report (No Crime)            NaN               NaN
# 268314            9496 Dead on Arrival (DOA)         3001.0               3.0
#
#         PUBLIC_WORKS_DIVISION          X          Y
# 266255                    6.0 -79.992377  40.444163
# 266336                    NaN        NaN        NaN
# 266467                    6.0 -79.979488  40.453677
# 267618                    NaN        NaN        NaN
# 268314                    5.0 -79.994135  40.408396

# %% [markdown]
# Data visualiazation

# %%
import geopandas
import matplotlib.pyplot as plt

# %%
neighborhoods = geopandas.read_file("Neighborhoods/Neighborhoods_.shp")
neighborhoods.plot()
# Out:
# <Axes: >

# %% [markdown]
# Convert Xs and Ys to actual locations

# %%
from shapely.geometry import Point
geometry = [Point(xy) for xy in zip(crime["X"], crime["Y"])]
gdf_crime = geopandas.GeoDataFrame(crime, geometry=geometry, crs="EPSG:4326")

# %% [markdown]
# Assign crime locations to neighborhoods

# %%
crime_with_neighborhood = geopandas.sjoin(gdf_crime, neighborhoods, how="left", predicate="within")

# %%
crime_counts = crime_with_neighborhood.groupby("hood").size().reset_index(name="CrimeCount")
crime_counts = crime_counts.sort_values("CrimeCount", ascending=False)  # 可选，查看高低
crime_counts.head()
# Out:
#                          hood  CrimeCount
# 16  Central Business District        4555
# 71           South Side Flats        3256
# 15                    Carrick        2167
# 67                  Shadyside        1642
# 76        Squirrel Hill South        1530

# %%
neighborhoods = neighborhoods.merge(crime_counts, on="hood", how="left")
neighborhoods["CrimeCount"] = neighborhoods["CrimeCount"].fillna(0)

# %%
neighborhoods.plot(column="CrimeCount", cmap="Reds", legend=True, figsize=(10,8))
# Out:
# <Axes: >

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /ihome/cmpinf0010_2025s/xil458/.local/lib/python3.11/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /ihome/crc/install/jupyterhub/hub4.0.2/lib/python3.11/site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.6.0 in /ihome/crc/install/jupyterhub/hub4.0.2/lib/python3.11/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /ihome/cmpinf0010_2025s/xil458/.local/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /ihome/cmpinf0010_2025s/xil458/.local/lib/python3.11/site-packages (from scikit-learn) (3.6.0)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
neighborhoods["SafetyScore"] = scaler.fit_transform(neighborhoods[["CrimeCount"]]) * -1 + 1

neighborhoods.plot(column="SafetyScore", cmap="Greens", legend=True, figsize=(10,8))
plt.title("Neighborhood Safety Score (0=Most Dangerous, 1=Safest)")
# Out:
# Text(0.5, 1.0, 'Neighborhood Safety Score (0=Most Dangerous, 1=Safest)')

# %%
neighborhoods.sort_values("SafetyScore", ascending=False)[["hood", "SafetyScore"]].head()
